# %% [markdown]
# ### Named Entity Recognition
#     -- is applied on the pos tags given by nltk.pos_tag()

# %% [raw]
# sentence="The Eiffel Tower was built from 1887 to 1889 by French engineer Gustave Eiffel, whose company specialized in building metal frameworks and structures."
# """
# Person Eg: Krish C Naik
# Place Or Location Eg: India
# Date Eg: September,24-09-1989
# Time  Eg: 4:30pm
# Money Eg: 1 million dollar
# Organization Eg: iNeuron Private Limited
# Percent Eg: 20%, twenty percent
# """

# %%
sentence = "The Eiffel Tower was built from 1887 to 1889 by Gustave Eiffel, whose company specialized in building metal frameworks and structures."

# %%
import nltk

words = nltk.word_tokenize(sentence)

# %%
words
# Out:
# ['The',
#  'Eiffel',
#  'Tower',
#  'was',
#  'built',
#  'from',
#  '1887',
#  'to',
#  '1889',
#  'by',
#  'Gustave',
#  'Eiffel',
#  ',',
#  'whose',
#  'company',
#  'specialized',
#  'in',
#  'building',
#  'metal',
#  'frameworks',
#  'and',
#  'structures',
#  '.']

# %%
tag_elements = nltk.pos_tag(words)
tag_elements
# Out:
# [('The', 'DT'),
#  ('Eiffel', 'NNP'),
#  ('Tower', 'NNP'),
#  ('was', 'VBD'),
#  ('built', 'VBN'),
#  ('from', 'IN'),
#  ('1887', 'CD'),
#  ('to', 'TO'),
#  ('1889', 'CD'),
#  ('by', 'IN'),
#  ('Gustave', 'NNP'),
#  ('Eiffel', 'NNP'),
#  (',', ','),
#  ('whose', 'WP$'),
#  ('company', 'NN'),
#  ('specialized', 'VBD'),
#  ('in', 'IN'),
#  ('building', 'NN'),
#  ('metal', 'NN'),
#  ('frameworks', 'NNS'),
#  ('and', 'CC'),
#  ('structures', 'NNS'),
#  ('.', '.')]

# %%
nltk.download("maxent_ne_chunker")
nltk.download("maxent_ne_chunker_tab")
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/shankii/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /Users/shankii/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker_tab.zip.
# True

# %%
nltk.download("words")
# Out:
# [nltk_data] Downloading package words to /Users/shankii/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
nltk.ne_chunk(tag_elements).draw()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 nltk.ne_chunk(tag_elements).draw()
#
# File ~/Documents/AI/.venv/lib/python3.11/site-packages/nltk/tree/tree.py:759, in Tree.draw(self)
#     755 def draw(self):
#     756     """
#     757     Open a new window containing a graphical diagram of this tree.
#     758     """
# --> 759     from nltk.draw.tree import draw_trees
#     761     draw_trees(self)
#
# File ~/Documents/AI/.venv/lib/python3.11/site-packages/nltk/draw/tree.py:12
#       1 # Natural Language Toolkit: Graphical Representations for Trees
#       2 #
#       3 # Copyright (C) 2001-2024 NLTK Project
#       4 # Author: Edward Loper <edloper@gmail.com>
#       5 # URL: <https://www.nltk.org/>
#       6 # For license information, see LICENSE.TXT
#       8 """
#       9 Graphically display a Tree.
#      10 """
# ---> 12 from tkinter import IntVar, Menu, Tk
#      14 from nltk.draw.util import (
#      15     BoxWidget,
#      16     CanvasFrame,
#    (...)
#      20     TextWidget,
#      21 )
#      22 from nltk.tree import Tree
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/tkinter/__init__.py:38
#      35 import sys
#      36 import types
# ---> 38 import _tkinter # If this fails your Python may not be configured for Tk
#      39 TclError = _tkinter.TclError
#      40 from tkinter.constants import *
#
# ModuleNotFoundError: No module named '_tkinter'
